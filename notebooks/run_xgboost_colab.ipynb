# %% [markdown]
# # XGBoost — Stellar Classification
# Run on Colab GPU. Downloads OOF + test probabilities for local ensemble.

# %%
# !nvidia-smi

# %%
# %cd /content/

import os
REPO_URL = "https://github.com/cyunchaeskku/kaggle_predicting_stellar_class.git"
REPO_NAME = "kaggle_predicting_stellar_class"

if os.path.exists(REPO_NAME):
    print(f"Pulling latest changes for {REPO_NAME}...")
    # !cd {REPO_NAME} && git pull
else:
    print(f"Cloning {REPO_NAME}...")
    # !git clone {REPO_URL}
# %cd kaggle_predicting_stellar_class/
# %pwd
# Out:
# /content
# Pulling latest changes for kaggle_predicting_stellar_class...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (5/5), done.
# Unpacking objects: 100% (12/12), 1.64 KiB | 560.00 KiB/s, done.
# remote: Total 12 (delta 6), reused 12 (delta 6), pack-reused 0 (from 0)
# From https://github.com/cyunchaeskku/kaggle_predicting_stellar_class
#    a893e8a..801b8f9  master     -> origin/master
# Updating a893e8a..801b8f9
# Fast-forward
#  .claude/worktrees/concurrent-plotting-firefly |  1 +
#  notebooks/run_xgboost_colab.ipynb             | 62 ++++++++++++++++++---------
#  src/train_feature_v2.py                       |  4 +-
#  src/train_feature_v2b.py                      |  4 +-
#  src/train_xgboost.py                          |  4 +-
#  5 files changed, 49 insertions(+), 26 deletions(-)
#  create mode 160000 .claude/worktrees/concurrent-plotting-firefly
# /content/kaggle_predicting_stellar_class
# '/content/kaggle_predicting_stellar_class'

# %%
# %cd kaggle_predicting_stellar_class/

# %%
# !pip install xgboost --quiet

# %%
# !python3 src/train_xgboost.py \
    --device cuda \
    --output-dir outputs/xgboost_feature_v2b \
    --n-estimators 3000 \
    --early-stopping-rounds 100
# Out:
# [0]	validation_0-mlogloss:1.03486
# [100]	validation_0-mlogloss:0.13110
# [200]	validation_0-mlogloss:0.11282
# [300]	validation_0-mlogloss:0.10697
# [400]	validation_0-mlogloss:0.10360
# [500]	validation_0-mlogloss:0.10113
# [600]	validation_0-mlogloss:0.09932
# [700]	validation_0-mlogloss:0.09800
# [800]	validation_0-mlogloss:0.09705
# [900]	validation_0-mlogloss:0.09626
# [1000]	validation_0-mlogloss:0.09561
# [1100]	validation_0-mlogloss:0.09515
# [1200]	validation_0-mlogloss:0.09480
# [1300]	validation_0-mlogloss:0.09457
# [1400]	validation_0-mlogloss:0.09442
# [1500]	validation_0-mlogloss:0.09432
# [1600]	validation_0-mlogloss:0.09424
# [1700]	validation_0-mlogloss:0.09438
# [1703]	validation_0-mlogloss:0.09438
# fold=1 best_iter=1603 balanced_accuracy=0.964561
# [0]	validation_0-mlogloss:1.03507
# [100]	validation_0-mlogloss:0.13350
# [200]	validation_0-mlogloss:0.11562
# [300]	validation_0-mlogloss:0.10954
# [400]	validation_0-mlogloss:0.10623
# [500]	validation_0-mlogloss:0.10409
# [600]	validation_0-mlogloss:0.10238
# [700]	validation_0-mlogloss:0.10093
# [800]	validation_0-mlogloss:0.10004
# [900]	validation_0-mlogloss:0.09919
# [1000]	validation_0-mlogloss:0.09859
# [1100]	validation_0-mlogloss:0.09807
# [1200]	validation_0-mlogloss:0.09769
# [1300]	validation_0-mlogloss:0.09741
# [1400]	validation_0-mlogloss:0.09723
# [1500]	validation_0-mlogloss:0.09713
# [1600]	validation_0-mlogloss:0.09713
# [1636]	validation_0-mlogloss:0.09715
# fold=2 best_iter=1536 balanced_accuracy=0.964817
# [0]	validation_0-mlogloss:1.03497
# [100]	validation_0-mlogloss:0.13542
# [200]	validation_0-mlogloss:0.11766
# [300]	validation_0-mlogloss:0.11157
# [400]	validation_0-mlogloss:0.10798
# [500]	validation_0-mlogloss:0.10593
# [600]	validation_0-mlogloss:0.10425
# [700]	validation_0-mlogloss:0.10303
# [800]	validation_0-mlogloss:0.10191
# [900]	validation_0-mlogloss:0.10106
# [1000]	validation_0-mlogloss:0.10032
# [1100]	validation_0-mlogloss:0.09982
# [1200]	validation_0-mlogloss:0.09948
# [1300]	validation_0-mlogloss:0.09924
# [1400]	validation_0-mlogloss:0.09911
# [1500]	validation_0-mlogloss:0.09903
# [1600]	validation_0-mlogloss:0.09900
# [1700]	validation_0-mlogloss:0.09907
# [1704]	validation_0-mlogloss:0.09908
# fold=3 best_iter=1604 balanced_accuracy=0.963093
# [0]	validation_0-mlogloss:1.03483
# [100]	validation_0-mlogloss:0.13196
# [200]	validation_0-mlogloss:0.11436
# [300]	validation_0-mlogloss:0.10867
# [400]	validation_0-mlogloss:0.10549
# [500]	validation_0-mlogloss:0.10330
# [600]	validation_0-mlogloss:0.10158
# [700]	validation_0-mlogloss:0.10030
# [800]	validation_0-mlogloss:0.09922
# [900]	validation_0-mlogloss:0.09840
# [1000]	validation_0-mlogloss:0.09783
# [1100]	validation_0-mlogloss:0.09735
# [1200]	validation_0-mlogloss:0.09703
# [1300]	validation_0-mlogloss:0.09681
# [1400]	validation_0-mlogloss:0.09668
# [1500]	validation_0-mlogloss:0.09663
# [1600]	validation_0-mlogloss:0.09664
# [1652]	validation_0-mlogloss:0.09666
# fold=4 best_iter=1552 balanced_accuracy=0.964102
# [0]	validation_0-mlogloss:1.03505
# [100]	validation_0-mlogloss:0.13440
# [200]	validation_0-mlogloss:0.11601
# [300]	validation_0-mlogloss:0.11008
# [400]	validation_0-mlogloss:0.10688
# [500]	validation_0-mlogloss:0.10439
# [600]	validation_0-mlogloss:0.10263
# [700]	validation_0-mlogloss:0.10119
# [800]	validation_0-mlogloss:0.10008
# [900]	validation_0-mlogloss:0.09924
# [1000]	validation_0-mlogloss:0.09858
# [1100]	validation_0-mlogloss:0.09805
# [1200]	validation_0-mlogloss:0.09769
# [1300]	validation_0-mlogloss:0.09748
# [1400]	validation_0-mlogloss:0.09728
# [1500]	validation_0-mlogloss:0.09721
# [1600]	validation_0-mlogloss:0.09719
# [1626]	validation_0-mlogloss:0.09720
# fold=5 best_iter=1526 balanced_accuracy=0.964781
# oof_balanced_accuracy=0.964271
# oof_balanced_accuracy_tuned=0.966067
# class_multipliers=GALAXY:0.56150,QSO:1.29725,STAR:1.14125
#               precision    recall  f1-score   support
#
#       GALAXY    0.98911   0.95532   0.97192    377480
#          QSO    0.94686   0.97664   0.96152    117143
#         STAR    0.86945   0.96624   0.91529     82724
#
#     accuracy                        0.96121    577347
#    macro avg    0.93514   0.96607   0.94958    577347
# weighted avg    0.96339   0.96121   0.96170    577347
#
# wrote_submission=outputs/xgboost_feature_v2b/submission.csv rows=247435
# wrote_test_probabilities=outputs/xgboost_feature_v2b/test_probabilities.csv rows=247435

# %%
from google.colab import files
files.download('outputs/xgboost_feature_v2b/oof_predictions.csv')
files.download('outputs/xgboost_feature_v2b/test_probabilities.csv')
files.download('outputs/xgboost_feature_v2b/submission.csv')
